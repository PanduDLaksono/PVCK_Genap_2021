# %% [markdown]
# <a href="https://colab.research.google.com/github/PanduDLaksono/PVCK_Genap_2021/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #load gambar di phyton
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list url untuk mendapatkan gambar
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]

# Membaca dan menampilkan gambar

# looping untuk url pada list diatas

for url in urls :
  image = io.imread(url)                          # membaca gambar
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # mengubah ukuran gambar menjadi setengah
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  # conversi ke RGB
  final_frame = cv.hconcat((image, image_2))      # concatenate gambar
  cv2_imshow(final_frame)                         # menampilkan gambar
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7FC0AD9D8C18>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FC0AD9D8B70>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FC0AD9D8F98>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi gambar : tinggi x lebar = ", tinggi , " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi gambar : tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7FC0B0842F60>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal di tengah image

for y in range (lebar):
  image_3[int((tinggi)/2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FC0A5C97358>

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
#
#   Jawab : mudah dalam penggunaan, tidak perlu menginstall aplikasi, dapat langsung disimpan kedalam repository di github, muncul saran code saat menulis script
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
#   Jawab :
#   - numpy digunakan untuk memanipulasi nilai array,
#   - pandas digunakan untuk memanipulasi data nilai,
#   - CV2 digunakan untuk memanipulasi data gambar yang akan ditampilkan
#   - Skimage digunakan untuk pemprosesan gambar pada phyton
#   - Matplotlib untuk visualisasi data
#
#   untuk libraby digunakan semuanya dalam praktikum tersebut
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#   ![Untitled.png](data:image/png;base64,...).
#
#   Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
#   Jawab : kode program tersebut digunakan untuk merubah ukuran gambar pada variable image dengan tinggi dan lebar menjadi setengah
#
# 4. Perhatikan potongan kode progam berikut :
#
#   ![image.png](data:image/png;base64,...)
#
#   Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
#   Jawab : kode program diatas digunakan untuk perubah  warna pixel yang ada pada gambar menjadi putih dengan format RGB
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi  ataupun rendah!
#
#   Jawab : semakin besar jumlah pixel dalam gambar, semakin tinggi juga resolusi/ukuran pada gambar dan semakin jernih saat gambar ditampilkan, begitu juga sebaliknya jika resolusi gambar rendah, maka gambar yang ditampilkan menjadi tindak jelas karena jumlah pixel di gambar sedikit

# %% [markdown]
# **TUGAS**
# 1. Buatlah garis vertikal dan diagonal menyilang pada output gambar
#
# ![image.png](data:image/png;base64,...)

# %%
# membuat garis vertikal di gambar

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
  image_4[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FC0A5BFE4A8>

# %%
# membuat garis diagonal
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

l1,t1 = 0,0
l2,t2 = lebar, tinggi
l3,t3 = 0, tinggi
l4,t4 = lebar, 0

image_5 = cv.line(image_5,(l1,t1),(l2,t2),(255,255,255))
image_5 = cv.line(image_5,(l3,t3),(l4,t4),(255,255,255))


final_frame = cv.hconcat((image_2, image_5))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FC0A5BFEF60>
